# %%
import pandas as pd
df=pd.read_csv("/home/futures/Downloads/FDNY - FDNY.csv")
df
# Out:
#                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                  Engine 10/Ladder 10
# 2                                             Engine 6
# 3    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                             Ladder 8
# ..                                                 ...
# 213                  Engine 162/Ladder 82/Battalion 23
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                          Engine 168/EMS Station 23
# 217                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             42 South Street      Manhattan
# 1          124 Liberty Street      Manhattan
# 2           49 Beekman Street      Manhattan
# 3        100-104 Duane Street      Manhattan
# 4       14 North Moore Street      Manhattan
# ...

# %%
df.count()
# Out:
# FacilityName       218
# FacilityAddress    218
# Borough            218
# dtype: int64

# %%
df['Borough'].value_counts()
# Out:
# Brooklyn         66
# Queens           50
# Manhattan        48
# Bronx            34
# Staten Island    20
# Name: Borough, dtype: int64

# %%
df.drop('FacilityAddress',axis=1,inplace=True)

# %%
df1=df.loc[df['Borough']=='Manhattan']
df1
# Out:
#                                          FacilityName    Borough
# 0                                  Engine 4/Ladder 15  Manhattan
# 1                                 Engine 10/Ladder 10  Manhattan
# 2                                            Engine 6  Manhattan
# 3   Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...  Manhattan
# 4                                            Ladder 8  Manhattan
# 5                                   Engine 9/Ladder 6  Manhattan
# 6                     Engine 15/Ladder 18/Battalion 4  Manhattan
# 7                                 Engine 28/Ladder 11  Manhattan
# 8                                            Engine 5  Manhattan
# 9                                           Engine 55  Manhattan
# 10                               Ladder 20/Division 1  Manhattan
# 11                     Engine 24/Ladder 5/Battalion 2  Manhattan
# 12                                 Engine 33/Ladder 9  Manhattan
# ...
